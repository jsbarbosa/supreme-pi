# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal as signal
# %matplotlib inline

# %%
data = np.genfromtxt("DHT_results.csv", delimiter = ",")

# %%
plt.plot(data[:,1])
plt.ylabel("Temperature (C)")
plt.show()

# %%
#plt.plot(data[:,2])
filtered = signal.medfilt(data[:,2], kernel_size=501)
plt.plot(filtered)
plt.ylabel("Humidity (%)")
plt.show()
