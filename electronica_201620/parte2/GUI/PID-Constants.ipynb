# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = np.genfromtxt('Ziegler–Nichols.csv', delimiter=",")
time = data[:, 0]
voltage = data[:, 1]
error = data[:, -1]

# %%
plt.plot(time, error)

# %%
pos = np.where(time<10)

time = time[pos]
error = error[pos]

plt.plot(time, error)
N = len(error)

fourier = np.fft.fft(error)
freq = np.fft.fftfreq(N, d = time[-1]/(N-1))

fourier.argsort()[::-1]
# Out:
# array([   0, 2996,    1, ...,    5, 2989,    8])

# %%
plt.plot(freq, np.real(fourier))
plt.xlim(0, 2)
# Out:
# (0, 2)

# %%
fourier[2996]
1/freq[2996]
# Out:
# -10.000607246124696

# %%
1/0.7
# Out:
# 1.4285714285714286
